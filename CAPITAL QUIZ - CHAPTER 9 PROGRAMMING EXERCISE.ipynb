# %% [markdown]
# # Q 2 - CAPITAL QUIZ
# Write a program that creates a dictionary containing the U.S. states as keys, and their capitals as values. (Use the Internet to get a list of the states and their capitals.) The program should then randomly quiz the user by displaying the name of a state and asking the user to enter that state’s capital. The program should keep a count of the number of correct and incorrect responses.

# %% [markdown]
# # ALGORITHM

# %%
# Import random module for shuffling the order of the questions
# Define main function
# Create dictionary name US STATES to map the states and capitals
# Welcome Message
# Initialize counter for correct and incorrect answers
# Create a shuffled list of state names
# Interate trhough the shuffled list of state names
# Check if the user's answer if correct
# Ask user if they want another question
# Display summary of results
# Call the main function

# %%
# Import random module for shuffling the order of the questions

import random

# Define main function

def main():

# Create dictionary name US STATES to map the states and capitals - This will be my module 

    us_states = {
                'Alabama': 'Montgomery',
    'Alaska': 'Juneau',
    'Arizona': 'Phoenix',
    'Arkansas': 'Little Rock',
    'California': 'Sacramento',
    'Colorado': 'Denver', # Going to ask ChatGPT to complete list for me to save time
    'Connecticut': 'Hartford',
    'Delaware': 'Dover',
    'Florida': 'Tallahassee',
    'Georgia': 'Atlanta',
    'Hawaii': 'Honolulu',
    'Idaho': 'Boise',
    'Illinois': 'Springfield',
    'Indiana': 'Indianapolis',
    'Iowa': 'Des Moines',
    'Kansas': 'Topeka',
    'Kentucky': 'Frankfort',
    'Louisiana': 'Baton Rouge',
    'Maine': 'Augusta',
    'Maryland': 'Annapolis',
    'Massachusetts': 'Boston',
    'Michigan': 'Lansing',
    'Minnesota': 'St. Paul',
    'Mississippi': 'Jackson',
    'Missouri': 'Jefferson City',
    'Montana': 'Helena',
    'Nebraska': 'Lincoln',
    'Nevada': 'Carson City',
    'New Hampshire': 'Concord',
    'New Jersey': 'Trenton',
    'New Mexico': 'Santa Fe',
    'New York': 'Albany',
    'North Carolina': 'Raleigh',
    'North Dakota': 'Bismarck',
    'Ohio': 'Columbus',
    'Oklahoma': 'Oklahoma City',
    'Oregon': 'Salem',
    'Pennsylvania': 'Harrisburg',
    'Rhode Island': 'Providence',
    'South Carolina': 'Columbia',
    'South Dakota': 'Pierre',
    'Tennessee': 'Nashville',
    'Texas': 'Austin',
    'Utah': 'Salt Lake City',
    'Vermont': 'Montpelier',
    'Virginia': 'Richmond',
    'Washington': 'Olympia',
    'West Virginia': 'Charleston',
    'Wisconsin': 'Madison',
    'Wyoming': 'Cheyenne'
    }

# Welcome Message

    print('Welcome to the U.S State Capitals Quiz')
    user_quiz(us_states)

# Define the user_quiz

def user_quiz(states_and_capitals):

# Initialize counter for correct and incorrect answers
# This will be the quiz summary

    correct_answers = 0
    incorrect_answers = 0

# Create a shuffled list of state names
    
    states = list(states_and_capitals.keys())
    random.shuffle(states)

# Interate trhough the shuffled list of state names

    for state in states:
        correct_capital = states_and_capitals[state] 
        # [state] is the key
        user_answer = input(f'What is the capital of {state}? ').strip()
        
# Check if the user's answer if correct
        if user_answer.lower() == correct_capital.lower():
            print('Correct!')
            correct_answers += 1
        else:
            print(f'Sorry, the correct capital is {correct_capital}.')
            incorrect_answers += 1


# Ask user if they want another question - I added this, because if not the quiz would go through all 50 states
          
        another_question = input('Do you want to answer another question about state capitals? (yes/y / no/n) ')
        if another_question not in['Yes', 'yes','Y', 'y']:
            break
    
# Display summary of results

    print('Quiz Summary: ')
    print(f'Correct Answers: {correct_answers}')
    print(f'Incorrect Answers: {incorrect_answers}')
    
# Call the main function

if __name__ == '__main__':
    main()
# Out:
# Welcome to the U.S State Capitals Quiz
# What is the capital of Mississippi? Jackson
# Correct!
# Do you want to answer another question about state capitals? (yes/y / no/n) Yes
# What is the capital of Idaho? Boise
# Correct!
# Do you want to answer another question about state capitals? (yes/y / no/n) y
# What is the capital of New Jersey? Trenton
# Correct!
# Do you want to answer another question about state capitals? (yes/y / no/n) yes
# What is the capital of Illinois? champaign
# Sorry, the correct capital is Springfield.
# Do you want to answer another question about state capitals? (yes/y / no/n) Y
# What is the capital of Alaska? Juneau
# Correct!
# Do you want to answer another question about state capitals? (yes/y / no/n) yes
# What is the capital of Minnesota? Vikings
# Sorry, the correct capital is St. Paul.
# Do you want to answer another question about state capitals? (yes/y / no/n) n
# Quiz Summary:
# Correct Answers: 4
# Incorrect Answers: 2

# %% [markdown]
# # Module
# I created two modules one called us_states for all the states and capitals and one call quiz for the correct and incorrect answers

# %%
from us_states import us_states
from quiz import user_quiz

def main():
    print('Welcome to the U.S State Capitals Quiz')
    user_quiz(us_states)

if __name__ == '__main__':
    main()
# Out:
# Welcome to the U.S State Capitals Quiz
# What is the capital of Iowa? Iowa city
# Sorry, the correct capital is Des Moines.
# Do you want to answer another question about state capitals? (yes/y / no/n) y
# What is the capital of New Hampshire? New hampshire city
# Sorry, the correct capital is Concord.
# Do you want to answer another question about state capitals? (yes/y / no/n) y
# What is the capital of Washington? Washington state
# Sorry, the correct capital is Olympia.
# Do you want to answer another question about state capitals? (yes/y / no/n) y
# What is the capital of Michigan? Lansing
# Correct!
# Do you want to answer another question about state capitals? (yes/y / no/n) y
# What is the capital of Kentucky? Kentucky City
# Sorry, the correct capital is Frankfort.
# Do you want to answer another question about state capitals? (yes/y / no/n) n
# Quiz Summary:
# Correct Answers: 1
# Incorrect Answers: 4
